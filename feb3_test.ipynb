# %%
jan01m = [4,4,8,3]
jan01e = [0,2,1,5]

jan02m = [4,9,1,1]
jan02e = [0,2,3,6]

jan03m = [9,6,1,2]
jan03e = [7,9,0,6]

jan04m = [2,6,7,7]
jan04e = [8,2,4,9]

jan05m = [4,6,7,4]
jan05e = [7,3,8,9]

jan06m = [4,1,4,9]
jan06e = [8,6,4,5]

jan07m = [6,6,6,8]
jan07e = [6,4,7,1]

jan08m = [9,2,7,5]
jan08e = [0,4,4,1]

jan09m = [1,4,8,5]
jan09e = [1,5,7,4]

jan10m = [4,9,9,7]
jan10e = [7,1,7,2]

jan11m = [0,4,0,1]
jan11e = [4,9,6,2]

jan12m = [9,7,8,5]
jan12e = [5,8,7,0]

jan13m = [0,6,8,5]
jan13e = [3,0,2,4]

jan14m = [5,3,0,4]
jan14e = [5,7,3,4]

jan15m = [0,2,2,5]
jan15e = [1,2,9,1]

jan16m = [7,4,9,9]
jan16e = [4,2,3,4]

jan17m = [4,2,0,1]
jan17e = [8,6,4,6]

jan18m = [0,0,8,2]
jan18e = [4,6,2,1]

jan19m = [7,2,9,2]
jan19e = [0,1,5,8]

jan20m = [4,0,6,6] 
jan20e = [1,8,5,6] 

jan21m = [0,8,8,0] 
jan21e = [1,4,4,8] 

jan22m = [6,9,8,6] 
jan22e = [2,4,3,6] 

jan23m = [3,5,1,2] 
jan23e = [2,8,0,5] 

jan24m = [4,6,5,9] 
jan24e = [4,5,6,7] 

jan25m = [9,1,7,3] 
jan25e = [3,4,0,6] 

jan26m = [7,5,5,1] 
jan26e = [3,3,2,3] 

jan27m = [0,5,5,2] 
jan27e = [2,8,4,6] 

jan28m = [2,3,2,6] 
jan28e = [9,1,4,2]

jan29m = [3,2,3,8]
jan29e = [1,7,2,9]

jan30m = [0,0,2,5]
jan30e = [4,7,0,3]

jan31m = [8,1,8,5]
jan31e = [1,0,7,1]

feb01m = [8,2,2,2]
feb01e = [8,4,3,5]

feb02m = [7,9,6,5]
feb02e = [7,3,3,3]

feb03m = [2,0,2,8]
feb03e = [0,4,7,7]

feb04m = [4,5,3,3]
feb04e = [5,5,7,2]

feb05m = [9,1,3,1]
feb05e = [3,5,1,6]

feb06m = [5,3,4,3]
feb06e = [5,8,3,9]

feb07m = [3,6,2,5]
feb07e = [0,7,0,1]

feb08m = [2,1,7,9]
feb08e = [1,9,4,6]

feb09m = [6,9,5,8]
feb09e = [1,9,2,5]

feb10m = [0,9,3,7]
feb10e = [0,4,9,4]

feb11m = [3,4,9,9]
feb11e = [2,6,4,5]

feb12m = [4,8,4,4]
feb12e = [0,9,0,0]

feb13m = [8,6,5,1]
feb13e = [7,1,8,8]

feb14m = [4,0,4,9]
feb14e = [0,6,8,5]

feb15m = [0,3,1,2]
feb15e = [9,1,7,6]

feb16m = [5,0,6,7]
feb16e = [3,0,1,4]

feb17m = [1,1,6,3]
feb17e = [3,1,4,7]

feb18m = [1,7,4,5]
feb18e = [0,7,0,5]

feb19m = [8,0,8,9]
feb19e = [0,2,1,7]

feb20m = [2,7,0,1]
feb20e = [3,3,2,4]

feb21m = [0,2,8,0]
feb21e = [7,5,5,1]

feb22m = [1,2,6,5]
feb22e = [5,8,3,6]

feb23m = [1,7,9,0]
feb23e = [2,6,9,1]

feb24m = [0,3,3,1]
feb24e = [7,8,3,2]

feb25m = [9,0,8,3]
feb25e = [9,8,1,8]

feb26m = [2,4,7,3]
feb26e = [7,5,4,7]

feb27m = [9,7,9,6]
feb27e = [8,0,4,6]

feb28m = [0,0,3,1]
feb28e = [0,9,8,7]

list_of_dates.append(jan01m, jan01e, jan02m, jan02e, jan03m, jan03e, jan04m, jan04e, jan05m, jan05e, jan06m, jan06e, jan07m, jan07e, jan08m, jan08e, jan09m, jan09e, jan10m, jan10e,
                     jan11m, jan11e, jan12m, jan12e, jan13m, jan13e, jan14m, jan14e, jan15m, jan15e, jan16m, jan16e, jan17m, jan17e, jan18m, jan18e, jan19m, jan19e, jan20m, jan20e,
                     jan21m, jan21e, jan22m, jan22e, jan23m, jan23e, jan24m, jan24e, jan25m, jan25e, jan26m, jan26e, jan27m, jan27e, jan28m, jan28e, jan29m, jan29e, jan30m, jan30e, jan31m, jan31e,
                     feb01m, feb01e, feb02m, feb02e, feb03m, feb03e, feb04m, feb04e, feb05m, feb05e, feb06m, feb06e, feb07m, feb07e, feb08m, feb08e, feb09m, feb09e, feb10m, feb10e,
                     feb11m, feb11e, feb12m, feb12e, feb13m, feb13e, feb14m, feb14e, feb15m, feb15e, feb16m, feb16e, feb17m, feb17e, feb18m, feb18e, feb19m, feb19e, feb20m, feb20e,
                     feb21m, feb21e, feb22m, feb22e, feb23m, feb23e, feb24m, feb24e, feb25m, feb25e, feb26m, feb26e, feb27m, feb27e, feb28m, feb28e)

# %%
def method_two(previous, current, next_win):

    # fill in current winning numbers
    c1 = current[0]
    c2 = current[1]
    c3 = current[2]
    c4 = current[3]

    # fill in the previous winning numbers
    p1 = previous[0]
    p2 = previous[1]
    p3 = previous[2]
    p4 = previous[3]

    # create the rows back towards current winning numbers

    previous_win = [p1, p2, p3, p4] 
    current_win = [c1, c2, c3, c4]
    
    row1 = [p1+c1, p2+c2, p3+c3, p4+c4]
    for index, row_val in enumerate(row1):
        if(row_val >= 10):
            row1[index] -= 10
    
    row2 = [p1+row1.copy()[0], p2+row1.copy()[1], p3+row1.copy()[2], p4+row1.copy()[3]]
    for index, row_val in enumerate(row2):
        if(row_val >= 10):
            row2[index] -= 10
    
    row3 = [p1+row2.copy()[0], p2+row2.copy()[1], p3+row2.copy()[2], p4+row2.copy()[3]]
    for index, row_val in enumerate(row3):
        if(row_val >= 10):
            row3[index] -= 10
    
    row4 = [p1+row3.copy()[0], p2+row3.copy()[1], p3+row3.copy()[2], p4+row3.copy()[3]]
    for index, row_val in enumerate(row4):
        if(row_val >= 10):
            row4[index] -= 10
    
    row5 = [p1+row4.copy()[0], p2+row4.copy()[1], p3+row4.copy()[2], p4+row4.copy()[3]]
    for index, row_val in enumerate(row5):
        if(row_val >= 10):
            row5[index] -= 10
    
    row6 = [p1+row5.copy()[0], p2+row5.copy()[1], p3+row5.copy()[2], p4+row5.copy()[3]]
    for index, row_val in enumerate(row6):
        if(row_val >= 10):
            row6[index] -= 10
    
    row7 = [p1+row6.copy()[0], p2+row6.copy()[1], p3+row6.copy()[2], p4+row6.copy()[3]]
    for index, row_val in enumerate(row7):
        if(row_val >= 10):
            row7[index] -= 10
    
    row8 = [p1+row7.copy()[0], p2+row7.copy()[1], p3+row7.copy()[2], p4+row7.copy()[3]]
    for index, row_val in enumerate(row8):
        if(row_val >= 10):
            row8[index] -= 10
    
    row9 = [p1+row8.copy()[0], p2+row8.copy()[1], p3+row8.copy()[2], p4+row8.copy()[3]]
    for index, row_val in enumerate(row9):
        if(row_val >= 10):
            row9[index] -= 10

    row10 = [p1+row9.copy()[0], p2+row9.copy()[1], p3+row9.copy()[2], p4+row9.copy()[3]]
    for index, row_val in enumerate(row10):
        if(row_val >= 10):
            row10[index] -= 10        


    #print("Previous WIN Numbers")
    #print(previous_win)
    print("Current WIN Numbers")
    print(current_win)
    print("============")
    print(row1)
    print(row2)
    print(row3)
    print(row4)
    print(row5)
    print(row6)
    print(row7)
    print(row8)
    print(row9)
    print("============")
    print(next_win)

# %%
jan17m = [0,0,3,1]
jan17e = [0,9,8,7]

special = [3,6,9,3]
method_two(special, jan17m, jan17e)

1790
2691
331
7832
9083
9818
2473
7547
9796
8046
31
987
# Out:
# Current WIN Numbers
# [0, 0, 3, 1]
# ...
# [3, 6, 2, 4]
# [6, 2, 1, 7]
# [9, 8, 0, 0]
# [2, 4, 9, 3]
# [5, 0, 8, 6]
# [8, 6, 7, 9]
# [1, 2, 6, 2]
# [4, 8, 5, 5]
# [7, 4, 4, 8]
# ...
# [0, 9, 8, 7]
# 987

# %%
previous_win = [p1, p2, p3, p4]
current_win = [c1, c2, c3, c4]

def generate_rows(prev, curr, iterations=10):
    rows = []
    current = [p + c for p, c in zip(prev, curr)]
    current = [val - 10 if val >= 10 else val for val in current]
    rows.append(current)
    
    for _ in range(iterations - 1):
        current = [p + r for p, r in zip(prev, current)]
        current = [val - 10 if val >= 10 else val for val in current]
        rows.append(current)
    
    return rows

rows = generate_rows(previous_win, current_win)

print("Current WIN Numbers")
print(current_win)
print("============")
for i, row in enumerate(rows, start=1):
    print(f"Row{i}: {row}")
print("============")
print("Next WIN Numbers")
print(rows[-1])

# %%
# Initial data
jan01m = [4, 4, 8, 3]
jan01e = [0, 2, 1, 5]
jan02m = [4, 9, 1, 1]
jan02e = [0, 2, 3, 6]
jan03m = [9, 6, 1, 2]
jan03e = [7, 9, 0, 6]

# All day/time pairs in sequence
data_pairs = [
    (jan01m, jan01e),
    (jan01e, jan02m),
    (jan02m, jan02e),
    (jan02e, jan03m),
    (jan03m, jan03e)
]

# Function to generate rows based on previous and current wins
def generate_rows(prev, curr, iterations=10):
    rows = []
    current = [p + c for p, c in zip(prev, curr)]
    current = [val - 10 if val >= 10 else val for val in current]
    rows.append(current)
    
    for _ in range(iterations - 1):
        current = [p + r for p, r in zip(prev, current)]
        current = [val - 10 if val >= 10 else val for val in current]
        rows.append(current)
    
    return rows

# Start the chaining process
all_results = []

for index, (prev, curr) in enumerate(data_pairs):
    print(f"\n=== Processing Pair {index + 1} ===")
    print(f"Previous Win: {prev}")
    print(f"Current Win : {curr}")
    
    result_rows = generate_rows(prev, curr)
    for i, row in enumerate(result_rows, 1):
        print(f"Row{i}: {row}")
    
    # Store final row for potential use
    next_prev = result_rows[-1]
    all_results.append(result_rows)
    
    # Update prev for next iteration
    if index + 1 < len(data_pairs):
        data_pairs[index + 1] = (next_prev, data_pairs[index + 1][1])

# Final prediction
print("\n=== Final Predicted WIN Numbers ===")
print(all_results[-1][-1])
